# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

df = pd.read_csv("APL_Logistics.csv", encoding="latin1")
df.head()
# Out:
#     Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0  DEBIT                         6                              4
# 1  DEBIT                         4                              4
# 2  DEBIT                         4                              4
# 3  DEBIT                         6                              4
# 4  DEBIT                         6                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0             159.69              472.45     Late delivery
# 1              48.71              167.96  Shipping on time
# 2              87.36              181.99  Shipping on time
# 3             -41.89              175.99     Late delivery
# 4              10.00               40.00     Late delivery
#
#    Late_delivery_risk  Category Id     Category Name Customer City  ...  \
# 0                   1            9  Cardio Equipment   Brownsville  ...
# 1                   0           29     Shop By Sport     Littleton  ...
# 2                   0           48      Water Sports     Littleton  ...
# 3                   1           48      Water Sports     Littleton  ...
# 4                   1           24   Women's Apparel     Littleton  ...
#
#   Order Item Quantity   Sales  Order Item Total Order Profit Per Order  \
# 0                   5  499.95            472.45                 159.69
# 1                   5  199.95            167.96                  48.71
# 2                   1  199.99            181.99                  87.36
# 3                   1  199.99            175.99                 -41.89
# 4                   1   50.00             40.00                  10.00
#
#       Order Region  Order State Order Status  \
# 0       South Asia  Maharashtra     COMPLETE
# 1  Central America       Cortés      ON_HOLD
# 2  Central America       Cortés      ON_HOLD
# 3      East of USA   Nueva York     COMPLETE
# 4      East of USA   Nueva York     COMPLETE
#
#                                     Product Name  Product Price  \
# 0              Nike Men's Free 5.0+ Running Shoe          99.99
# 1  Under Armour Girls' Toddler Spine Surge Runni          39.99
# 2                    Pelican Sunstream 100 Kayak         199.99
# 3                    Pelican Sunstream 100 Kayak         199.99
# 4           Nike Men's Dri-FIT Victory Golf Polo          50.00
#
#     Shipping Mode
# 0  Standard Class
# 1  Standard Class
# 2  Standard Class
# 3  Standard Class
# 4  Standard Class
#
# [5 rows x 40 columns]

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
#  10  Customer Country               180519 non-null  object
#  11  Customer Fname                 180519 non-null  object
#  12  Customer Id                    180519 non-null  int64
#  13  Customer Lname                 180511 non-null  object
#  14  Customer Segment               180519 non-null  object
#  15  Customer State                 180519 non-null  object
#  16  Customer Street                180519 non-null  object
#  17  Customer Zipcode               180516 non-null  float64
#  18  Department Id                  180519 non-null  int64
#  19  Department Name                180519 non-null  object
#  20  Latitude                       180519 non-null  float64
#  21  Longitude                      180519 non-null  float64
#  22  Market                         180519 non-null  object
#  23  Order City                     180519 non-null  object
#  24  Order Country                  180519 non-null  object
#  25  Order Customer Id              180519 non-null  int64
#  26  Order Item Discount            180519 non-null  float64
#  27  Order Item Discount Rate       180519 non-null  float64
#  28  Order Item Product Price       180519 non-null  float64
#  29  Order Item Profit Ratio        180519 non-null  float64
#  30  Order Item Quantity            180519 non-null  int64
#  31  Sales                          180519 non-null  float64
#  32  Order Item Total               180519 non-null  float64
#  33  Order Profit Per Order         180519 non-null  float64
#  34  Order Region                   180519 non-null  object
#  35  Order State                    180519 non-null  object
#  36  Order Status                   180519 non-null  object
#  37  Product Name                   180519 non-null  object
#  38  Product Price                  180519 non-null  float64
#  39  Shipping Mode                  180519 non-null  object
# dtypes: float64(13), int64(8), object(19)
# memory usage: 55.1+ MB
# (180519, 40)

# %%
df.isnull().sum()
# Out:
# Type                             0
# Days for shipping (real)         0
# Days for shipment (scheduled)    0
# Benefit per order                0
# Sales per customer               0
# Delivery Status                  0
# Late_delivery_risk               0
# Category Id                      0
# Category Name                    0
# Customer City                    0
# Customer Country                 0
# Customer Fname                   0
# Customer Id                      0
# Customer Lname                   8
# Customer Segment                 0
# Customer State                   0
# Customer Street                  0
# Customer Zipcode                 3
# Department Id                    0
# Department Name                  0
# Latitude                         0
# Longitude                        0
# Market                           0
# Order City                       0
# Order Country                    0
# Order Customer Id                0
# Order Item Discount              0
# Order Item Discount Rate         0
# Order Item Product Price         0
# Order Item Profit Ratio          0
# Order Item Quantity              0
# Sales                            0
# Order Item Total                 0
# Order Profit Per Order           0
# Order Region                     0
# Order State                      0
# Order Status                     0
# Product Name                     0
# Product Price                    0
# Shipping Mode                    0
# dtype: int64

# %%
df['Customer Lname'].isnull().sum()
# Out:
# np.int64(8)

# %%
df.drop(columns=['Customer Zipcode'], inplace=True)

# %%
df['Customer Lname'] = df['Customer Lname'].fillna('Unknown')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
#  10  Customer Country               180519 non-null  object
#  11  Customer Fname                 180519 non-null  object
#  12  Customer Id                    180519 non-null  int64
#  13  Customer Lname                 180519 non-null  object
#  14  Customer Segment               180519 non-null  object
#  15  Customer State                 180519 non-null  object
#  16  Customer Street                180519 non-null  object
#  17  Department Id                  180519 non-null  int64
#  18  Department Name                180519 non-null  object
#  19  Latitude                       180519 non-null  float64
#  20  Longitude                      180519 non-null  float64
#  21  Market                         180519 non-null  object
#  22  Order City                     180519 non-null  object
#  23  Order Country                  180519 non-null  object
#  24  Order Customer Id              180519 non-null  int64
#  25  Order Item Discount            180519 non-null  float64
#  26  Order Item Discount Rate       180519 non-null  float64
#  27  Order Item Product Price       180519 non-null  float64
#  28  Order Item Profit Ratio        180519 non-null  float64
#  29  Order Item Quantity            180519 non-null  int64
#  30  Sales                          180519 non-null  float64
#  31  Order Item Total               180519 non-null  float64
#  32  Order Profit Per Order         180519 non-null  float64
#  33  Order Region                   180519 non-null  object
#  34  Order State                    180519 non-null  object
#  35  Order Status                   180519 non-null  object
#  36  Product Name                   180519 non-null  object
#  37  Product Price                  180519 non-null  float64
#  38  Shipping Mode                  180519 non-null  object
# dtypes: float64(12), int64(8), object(19)
# memory usage: 53.7+ MB

# %%
df.isnull().sum()
# Out:
# Type                             0
# Days for shipping (real)         0
# Days for shipment (scheduled)    0
# Benefit per order                0
# Sales per customer               0
# Delivery Status                  0
# Late_delivery_risk               0
# Category Id                      0
# Category Name                    0
# Customer City                    0
# Customer Country                 0
# Customer Fname                   0
# Customer Id                      0
# Customer Lname                   0
# Customer Segment                 0
# Customer State                   0
# Customer Street                  0
# Department Id                    0
# Department Name                  0
# Latitude                         0
# Longitude                        0
# Market                           0
# Order City                       0
# Order Country                    0
# Order Customer Id                0
# Order Item Discount              0
# Order Item Discount Rate         0
# Order Item Product Price         0
# Order Item Profit Ratio          0
# Order Item Quantity              0
# Sales                            0
# Order Item Total                 0
# Order Profit Per Order           0
# Order Region                     0
# Order State                      0
# Order Status                     0
# Product Name                     0
# Product Price                    0
# Shipping Mode                    0
# dtype: int64

# %%
df['Type'].unique()
# Out:
# array(['DEBIT', 'PAYMENT', 'TRANSFER', 'CASH'], dtype=object)

# %%
df['Type'].value_counts()
# Out:
# Type
# DEBIT       69295
# TRANSFER    49883
# PAYMENT     41725
# CASH        19616
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

payment_counts = df['Type'].value_counts()

plt.figure(figsize=(8,8))
plt.pie(
    payment_counts,
    labels=payment_counts.index,
    autopct='%1.1f%%',
    startangle=90
)

plt.title('Distribution of Payment Methods')
plt.axis('equal')  # makes it a perfect circle

plt.show()

# %%
# Dictionary of column categories

column_categories = {
    "Customer": [
        "Customer Id",
        "Customer Fname",
        "Customer Lname",
        "Customer Segment",
        "Customer City",
        "Customer Street",
        "Customer Country",
        "Customer State"
    ]
}

customer_df = df[column_categories["Customer"]]
customer_df.head()
# Out:
#    Customer Id Customer Fname Customer Lname Customer Segment Customer City  \
# 0            1        Richard      Hernandez         Consumer   Brownsville
# 1            2           Mary        Barrett         Consumer     Littleton
# 2            2           Mary        Barrett         Consumer     Littleton
# 3            2           Mary        Barrett         Consumer     Littleton
# 4            2           Mary        Barrett         Consumer     Littleton
#
#            Customer Street Customer Country Customer State
# 0       6303 Heather Plaza          EE. UU.             TX
# 1  9526 Noble Embers Ridge          EE. UU.             CO
# 2  9526 Noble Embers Ridge          EE. UU.             CO
# 3  9526 Noble Embers Ridge          EE. UU.             CO
# 4  9526 Noble Embers Ridge          EE. UU.             CO

# %%
product_columns = [
    "Category Id",
    "Category Name",
    "Department Id",
    "Department Name",
    "Product Name",
    "Product Price"
]

product_df = df[product_columns]
product_df.head(10)
# Out:
#    Category Id         Category Name  Department Id Department Name  \
# 0            9      Cardio Equipment              3        Footwear
# 1           29         Shop By Sport              5            Golf
# 2           48          Water Sports              7        Fan Shop
# 3           48          Water Sports              7        Fan Shop
# 4           24       Women's Apparel              5            Golf
# 5           43      Camping & Hiking              7        Fan Shop
# 6           46  Indoor/Outdoor Games              7        Fan Shop
# 7           46  Indoor/Outdoor Games              7        Fan Shop
# 8           45               Fishing              7        Fan Shop
# 9           17                Cleats              4         Apparel
#
#                                     Product Name  Product Price
# 0              Nike Men's Free 5.0+ Running Shoe          99.99
# 1  Under Armour Girls' Toddler Spine Surge Runni          39.99
# 2                    Pelican Sunstream 100 Kayak         199.99
# 3                    Pelican Sunstream 100 Kayak         199.99
# 4           Nike Men's Dri-FIT Victory Golf Polo          50.00
# 5  Diamondback Women's Serene Classic Comfort Bi         299.98
# 6               O'Brien Men's Neoprene Life Vest          49.98
# 7               O'Brien Men's Neoprene Life Vest          49.98
# 8      Field & Stream Sportsman 16 Gun Fire Safe         399.98
# 9               Perfect Fitness Perfect Rip Deck          59.99

# %%
order_columns = [
    "Order Customer Id",
    "Order City",
    "Order State",
    "Order Country",
    "Order Region",
    "Order Status"
]
order_df = df[order_columns]
order_df.head()
# Out:
#    Order Customer Id      Order City  Order State   Order Country  \
# 0                  1          Mumbai  Maharashtra           India
# 1                  2  San Pedro Sula       Cortés        Honduras
# 2                  2  San Pedro Sula       Cortés        Honduras
# 3                  2   New York City   Nueva York  Estados Unidos
# 4                  2   New York City   Nueva York  Estados Unidos
#
#       Order Region Order Status
# 0       South Asia     COMPLETE
# 1  Central America      ON_HOLD
# 2  Central America      ON_HOLD
# 3      East of USA     COMPLETE
# 4      East of USA     COMPLETE

# %%
sales_profit_columns = [
    "Sales",
    "Sales per customer",
    "Benefit per order",
    "Order Profit Per Order",
    "Order Item Profit Ratio",
    "Order Item Total"
]
sales_profit_df = df[sales_profit_columns]
sales_profit_df.head()
# Out:
#     Sales  Sales per customer  Benefit per order  Order Profit Per Order  \
# 0  499.95              472.45             159.69                  159.69
# 1  199.95              167.96              48.71                   48.71
# 2  199.99              181.99              87.36                   87.36
# 3  199.99              175.99             -41.89                  -41.89
# 4   50.00               40.00              10.00                   10.00
#
#    Order Item Profit Ratio  Order Item Total
# 0                     0.34            472.45
# 1                     0.29            167.96
# 2                     0.48            181.99
# 3                    -0.24            175.99
# 4                     0.25             40.00

# %%
pricing_columns = [
    "Order Item Product Price",
    "Order Item Discount",
    "Order Item Discount Rate",
    "Order Item Quantity"
]
pricing_df = df[pricing_columns]
pricing_df.head()
# Out:
#    Order Item Product Price  Order Item Discount  Order Item Discount Rate  \
# 0                     99.99                27.50                      0.06
# 1                     39.99                31.99                      0.16
# 2                    199.99                18.00                      0.09
# 3                    199.99                24.00                      0.12
# 4                     50.00                10.00                      0.20
#
#    Order Item Quantity
# 0                    5
# 1                    5
# 2                    1
# 3                    1
# 4                    1

# %%
shipping_columns = [
    "Days for shipping (real)",
    "Days for shipment (scheduled)",
    "Shipping Mode",
    "Delivery Status",
    "Late_delivery_risk"
]
shipping_df = df[shipping_columns]
shipping_df.head()
# Out:
#    Days for shipping (real)  Days for shipment (scheduled)   Shipping Mode  \
# 0                         6                              4  Standard Class
# 1                         4                              4  Standard Class
# 2                         4                              4  Standard Class
# 3                         6                              4  Standard Class
# 4                         6                              4  Standard Class
#
#     Delivery Status  Late_delivery_risk
# 0     Late delivery                   1
# 1  Shipping on time                   0
# 2  Shipping on time                   0
# 3     Late delivery                   1
# 4     Late delivery                   1

# %%
geography_columns = [
    "Latitude",
    "Longitude",
    "Market"
]

geography_df = df[geography_columns]
geography_df.head()
# Out:
#     Latitude   Longitude        Market
# 0  25.953648  -97.507683  Pacific Asia
# 1  38.375595 -104.726021         LATAM
# 2  38.375595 -104.726021         LATAM
# 3  38.375595 -104.726021          USCA
# 4  38.375595 -104.726021          USCA

# %%
df.dtypes # wrong dts
# Out:
# Type                              object
# Days for shipping (real)           int64
# Days for shipment (scheduled)      int64
# Benefit per order                float64
# Sales per customer               float64
# Delivery Status                   object
# Late_delivery_risk                 int64
# Category Id                        int64
# Category Name                     object
# Customer City                     object
# Customer Country                  object
# Customer Fname                    object
# Customer Id                        int64
# Customer Lname                    object
# Customer Segment                  object
# Customer State                    object
# Customer Street                   object
# Department Id                      int64
# Department Name                   object
# Latitude                         float64
# Longitude                        float64
# Market                            object
# Order City                        object
# Order Country                     object
# Order Customer Id                  int64
# Order Item Discount              float64
# Order Item Discount Rate         float64
# Order Item Product Price         float64
# Order Item Profit Ratio          float64
# Order Item Quantity                int64
# Sales                            float64
# Order Item Total                 float64
# Order Profit Per Order           float64
# Order Region                      object
# Order State                       object
# Order Status                      object
# Product Name                      object
# Product Price                    float64
# Shipping Mode                     object
# dtype: object

# %%
for col in df.select_dtypes(include=['number']).columns:
    count = (df[col] < 0).sum()
    if count > 0:
        print(f"{col}: {count} negative values")
# Out:
# Benefit per order: 33784 negative values
# Latitude: 9 negative values
# Longitude: 180414 negative values
# Order Item Profit Ratio: 33784 negative values
# Order Profit Per Order: 33784 negative values

# %%
numeric_df = df.select_dtypes(include=np.number)

for col in numeric_df.columns:
    Q1 = numeric_df[col].quantile(0.25)
    Q3 = numeric_df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = numeric_df[(numeric_df[col] < lower_bound) | (numeric_df[col] > upper_bound)]

    print(f"{col}: {len(outliers)} outliers")
# Out:
# Days for shipping (real): 0 outliers
# Days for shipment (scheduled): 0 outliers
# Benefit per order: 18942 outliers
# Sales per customer: 1943 outliers
# Late_delivery_risk: 0 outliers
# Category Id: 0 outliers
# Customer Id: 1198 outliers
# Department Id: 362 outliers
# Latitude: 9 outliers
# Longitude: 1414 outliers
# Order Customer Id: 1198 outliers
# Order Item Discount: 7537 outliers
# Order Item Discount Rate: 0 outliers
# Order Item Product Price: 2048 outliers
# Order Item Profit Ratio: 17354 outliers
# Order Item Quantity: 0 outliers
# Sales: 488 outliers
# Order Item Total: 1943 outliers
# Order Profit Per Order: 18942 outliers
# Product Price: 2048 outliers

# %%
import pandas as pd

# Columns to analyze for outliers
outlier_columns = [
    "Benefit per order",
    "Sales per customer",
    "Order Item Discount",
    "Order Item Product Price",
    "Order Item Profit Ratio",
    "Sales",
    "Order Item Total",
    "Order Profit Per Order",
    "Product Price"
]

# Dictionary to store outlier DataFrames
outlier_dfs = {}

for col in outlier_columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outlier_dfs[col] = df[(df[col] < lower) | (df[col] > upper)]

print("Outlier DataFrames created successfully!")
# Out:
# Outlier DataFrames created successfully!

# %%
import matplotlib.pyplot as plt

# Columns with outliers
outlier_columns = [
    "Benefit per order",
    "Sales per customer",
    "Order Item Discount",
    "Order Item Product Price",
    "Order Item Profit Ratio",
    "Sales",
    "Order Item Total",
    "Order Profit Per Order",
    "Product Price"
]

for col in outlier_columns:
    # IQR calculation
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outlier_count = ((df[col] < lower) | (df[col] > upper)).sum()

    print("=" * 80)
    print(f"Column Name       : {col}")
    print(f"Number of Outliers: {outlier_count}")
    print("=" * 80)


    plt.figure(figsize=(8, 3))
    plt.boxplot(df[col], vert=False)
    plt.title(f"Box Plot of {col}")
    plt.xlabel(col)
    plt.grid(axis='x', linestyle='--', alpha=0.6)
    plt.show()
# Out:
# ================================================================================
# Column Name       : Benefit per order
# Number of Outliers: 18942
# ================================================================================
# ================================================================================
# Column Name       : Sales per customer
# Number of Outliers: 1943
# ================================================================================
# ================================================================================
# Column Name       : Order Item Discount
# Number of Outliers: 7537
# ================================================================================
# ================================================================================
# Column Name       : Order Item Product Price
# Number of Outliers: 2048
# ================================================================================
# ================================================================================
# Column Name       : Order Item Profit Ratio
# Number of Outliers: 17354
# ================================================================================
# ================================================================================
# Column Name       : Sales
# Number of Outliers: 488
# ================================================================================
# ================================================================================
# Column Name       : Order Item Total
# Number of Outliers: 1943
# ================================================================================
# ================================================================================
# Column Name       : Order Profit Per Order
# Number of Outliers: 18942
# ================================================================================
# ================================================================================
# Column Name       : Product Price
# Number of Outliers: 2048
# ================================================================================

# %%
import matplotlib.pyplot as plt

numerical_columns = [
    "Benefit per order",
    "Sales per customer",
    "Order Item Discount",
    "Order Item Product Price",
    "Order Item Profit Ratio",
    "Order Item Quantity",
    "Sales",
    "Order Item Total",
    "Order Profit Per Order",
    "Product Price"
]

for col in numerical_columns:
    print("="*60)
    print(f"Histogram of {col}")
    print("="*60)

    plt.figure(figsize=(8,4))
    plt.hist(df[col], bins=30)
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()
# Out:
# ============================================================
# Histogram of Benefit per order
# ============================================================
# ============================================================
# Histogram of Sales per customer
# ============================================================
# ============================================================
# Histogram of Order Item Discount
# ============================================================
# ============================================================
# Histogram of Order Item Product Price
# ============================================================
# ============================================================
# Histogram of Order Item Profit Ratio
# ============================================================
# ============================================================
# Histogram of Order Item Quantity
# ============================================================
# ============================================================
# Histogram of Sales
# ============================================================
# ============================================================
# Histogram of Order Item Total
# ============================================================
# ============================================================
# Histogram of Order Profit Per Order
# ============================================================
# ============================================================
# Histogram of Product Price
# ============================================================

# %%
import seaborn as sns
import matplotlib.pyplot as plt

categorical_columns = [
    "Category Name",
    "Customer Segment",
    "Department Name",
    "Market",
    "Order Status",
    "Shipping Mode",
    "Delivery Status"
]

for col in categorical_columns:
    print("="*60)
    print(f"Count Plot of {col}")
    print("="*60)

    plt.figure(figsize=(10,5))
    sns.countplot(data=df, x=col)
    plt.xticks(rotation=45)
    plt.show()
# Out:
# ============================================================
# Count Plot of Category Name
# ============================================================
# ============================================================
# Count Plot of Customer Segment
# ============================================================
# ============================================================
# Count Plot of Department Name
# ============================================================
# ============================================================
# Count Plot of Market
# ============================================================
# ============================================================
# Count Plot of Order Status
# ============================================================
# ============================================================
# Count Plot of Shipping Mode
# ============================================================
# ============================================================
# Count Plot of Delivery Status
# ============================================================

# %%
scatter_pairs = [
    ("Sales", "Benefit per order"),
    ("Sales", "Order Profit Per Order"),
    ("Order Item Discount", "Sales"),
    ("Product Price", "Sales"),
    ("Order Item Quantity", "Sales")
]

for x, y in scatter_pairs:

    print("="*60)
    print(f"Scatter Plot: {x} vs {y}")
    print("="*60)

    plt.figure(figsize=(7,5))
    plt.scatter(df[x], df[y])

    plt.xlabel(x)
    plt.ylabel(y)

    plt.title(f"{x} vs {y}")

    plt.show()
# Out:
# ============================================================
# Scatter Plot: Sales vs Benefit per order
# ============================================================
# ============================================================
# Scatter Plot: Sales vs Order Profit Per Order
# ============================================================
# ============================================================
# Scatter Plot: Order Item Discount vs Sales
# ============================================================
# ============================================================
# Scatter Plot: Product Price vs Sales
# ============================================================
# ============================================================
# Scatter Plot: Order Item Quantity vs Sales
# ============================================================

# %%
# Create a new DataFrame with Sales >= 1750
sales_750_df = df[df["Sales"] >= 1750]

# Display the DataFrame


pd.set_option('display.max_columns', None)

sales_750_df
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 5217    TRANSFER                         2                              4
# 13617      DEBIT                         4                              4
# 15793      DEBIT                         5                              4
# 16778      DEBIT                         3                              4
# 19518      DEBIT                         5                              2
# 35671      DEBIT                         2                              2
# 59044      DEBIT                         3                              4
# 76906      DEBIT                         2                              1
# 83124      DEBIT                         5                              4
# 91112       CASH                         4                              4
# 116912     DEBIT                         2                              1
# 131583     DEBIT                         4                              4
# 143213     DEBIT                         2                              4
# 147133     DEBIT                         6                              4
# 148607     DEBIT                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# 5217              -952.56             1679.99  Advance shipping
# 13617            -1246.09             1699.99  Shipping on time
# 15793              721.60             1639.99     Late delivery
# 16778              473.20             1819.99  Advance shipping
# 19518            -4274.98             1899.99     Late delivery
# 35671              864.00             1799.99  Shipping on time
# 59044              520.00             1599.99  Advance shipping
# 76906              911.80             1939.99     Late delivery
# 83124              660.00             1759.99     Late delivery
# 91112              139.50             1859.99  Shipping on time
# 116912             187.58             1659.99     Late delivery
# 131583              45.00             1499.99  Shipping on time
# 143213              34.80             1739.99  Advance shipping
# 147133             264.96             1919.99     Late delivery
# 148607             686.07             1889.99  Shipping on time
#
#         Late_delivery_risk  Category Id      Category Name Customer City  \
# 5217                     0           10  Strength Training        Caguas
# 13617                    0           10  Strength Training        Caguas
# 15793                    1           10  Strength Training       Augusta
# 16778                    0           10  Strength Training         Bronx
# 19518                    1           10  Strength Training     Frankfort
# 35671                    0           10  Strength Training      Amarillo
# 59044                    0           10  Strength Training     San Diego
# 76906                    1           10  Strength Training        Caguas
# 83124                    1           10  Strength Training        Caguas
# 91112                    0           10  Strength Training        Caguas
# 116912                   1           10  Strength Training        Caguas
# 131583                   0           10  Strength Training        Caguas
# 143213                   0           10  Strength Training        Caguas
# 147133                   1           10  Strength Training       Seattle
# 148607                   0           10  Strength Training      Palatine
#
#        Customer Country Customer Fname  Customer Id Customer Lname  \
# 5217        Puerto Rico           Mary          382           Lane
# 13617       Puerto Rico      Catherine          986        Hawkins
# 15793           EE. UU.           Mary         1148       Anderson
# 16778           EE. UU.        Richard         1223          Perry
# 19518           EE. UU.           Mary         1428          Clark
# 35671           EE. UU.        Phillip         2564          Smith
# 59044           EE. UU.        Charles         4258         Rogers
# 76906       Puerto Rico           Mary         5533       Harrison
# 83124       Puerto Rico         Daniel         5946          Smith
# 91112       Puerto Rico          Amber         6517       Sheppard
# 116912      Puerto Rico          Helen         8462          Smith
# 131583      Puerto Rico       Victoria         9515          Smith
# 143213      Puerto Rico         Teresa        10351           Gray
# 147133          EE. UU.        Matthew        10637          Smith
# 148607          EE. UU.       Samantha        10744          Smith
#
#        Customer Segment Customer State           Customer Street  \
# 5217           Consumer             PR       7666 High Dale Bank
# 13617       Home Office             PR          3651 Rustic Cape
# 15793          Consumer             GA            7213 Cozy Quay
# 16778          Consumer             NY   1655 Little Bear Circle
# 19518          Consumer             KY             4311 Old Edge
# 35671         Corporate             TX        6068 Quaking Heath
# 59044         Corporate             CA          2650 Rocky Stead
# 76906          Consumer             PR  852 Rocky Brook Mountain
# 83124          Consumer             PR        4823 Golden Hollow
# 91112          Consumer             PR   2963 Indian Elk Pathway
# 116912      Home Office             PR          1577 Green Vista
# 131583         Consumer             PR       870 High View Close
# 143213      Home Office             PR          8021 Misty Plaza
# 147133         Consumer             WA         851 Blue Elk Walk
# 148607         Consumer             IL          5129 Indian Maze
#
#         Department Id Department Name   Latitude   Longitude  Market  \
# 5217                3        Footwear  18.247520  -66.025269  Europe
# 13617               3        Footwear  18.227577  -66.044533  Europe
# 15793               3        Footwear  33.521042  -82.049355  Europe
# 16778               3        Footwear  40.838802  -73.870995  Europe
# 19518               3        Footwear  38.118618  -84.967422  Europe
# 35671               3        Footwear  35.187542 -101.867622  Europe
# 59044               3        Footwear  32.760025 -117.248383  Europe
# 76906               3        Footwear  18.262022  -66.370590  Europe
# 83124               3        Footwear  18.237732  -66.370621  Europe
# 91112               3        Footwear  18.208799  -66.370499  Europe
# 116912              3        Footwear  18.251719  -66.370613  Europe
# 131583              3        Footwear  18.252848  -66.370529  Europe
# 143213              3        Footwear  18.288868  -66.370544  Europe
# 147133              3        Footwear  47.678699 -122.321762  Europe
# 148607              3        Footwear  42.111866  -88.048714  Europe
#
#                    Order City Order Country  Order Customer Id  \
# 5217                 Le Havre       Francia                382
# 13617                   Milan        Italia                986
# 15793               Marseille       Francia               1148
# 16778                 Rostock      Alemania               1223
# 19518                  Dudley   Reino Unido               1428
# 35671              Draguignan       Francia               2564
# 59044              Chelmsford   Reino Unido               4258
# 76906       Villenave-d'Ornon       Francia               5533
# 83124                   Genoa        Italia               5946
# 91112                Toulouse       Francia               6517
# 116912               Plymouth   Reino Unido               8462
# 131583             Colchester   Reino Unido               9515
# 143213                 Dublín       Irlanda              10351
# 147133                 Rennes       Francia              10637
# 148607  Sant Boi de Llobregat        España              10744
#
#         Order Item Discount  Order Item Discount Rate  \
# 5217                  320.0                      0.16
# 13617                 300.0                      0.15
# 15793                 360.0                      0.18
# 16778                 180.0                      0.09
# 19518                 100.0                      0.05
# 35671                 200.0                      0.10
# 59044                 400.0                      0.20
# 76906                  60.0                      0.03
# 83124                 240.0                      0.12
# 91112                 140.0                      0.07
# 116912                340.0                      0.17
# 131583                500.0                      0.25
# 143213                260.0                      0.13
# 147133                 80.0                      0.04
# 148607                110.0                      0.06
#
#         Order Item Product Price  Order Item Profit Ratio  \
# 5217                     1999.99                    -0.57
# 13617                    1999.99                    -0.73
# 15793                    1999.99                     0.44
# 16778                    1999.99                     0.26
# 19518                    1999.99                    -2.25
# 35671                    1999.99                     0.48
# 59044                    1999.99                     0.33
# 76906                    1999.99                     0.47
# 83124                    1999.99                     0.38
# 91112                    1999.99                     0.08
# 116912                   1999.99                     0.11
# 131583                   1999.99                     0.03
# 143213                   1999.99                     0.02
# 147133                   1999.99                     0.14
# 148607                   1999.99                     0.36
#
#         Order Item Quantity    Sales  Order Item Total  \
# 5217                      1  1999.99           1679.99
# 13617                     1  1999.99           1699.99
# 15793                     1  1999.99           1639.99
# 16778                     1  1999.99           1819.99
# 19518                     1  1999.99           1899.99
# 35671                     1  1999.99           1799.99
# 59044                     1  1999.99           1599.99
# 76906                     1  1999.99           1939.99
# 83124                     1  1999.99           1759.99
# 91112                     1  1999.99           1859.99
# 116912                    1  1999.99           1659.99
# 131583                    1  1999.99           1499.99
# 143213                    1  1999.99           1739.99
# 147133                    1  1999.99           1919.99
# 148607                    1  1999.99           1889.99
#
#         Order Profit Per Order     Order Region  \
# 5217                   -952.56   Western Europe
# 13617                 -1246.09  Southern Europe
# 15793                   721.60   Western Europe
# 16778                   473.20   Western Europe
# 19518                 -4274.98  Northern Europe
# 35671                   864.00   Western Europe
# 59044                   520.00  Northern Europe
# 76906                   911.80   Western Europe
# 83124                   660.00  Southern Europe
# 91112                   139.50   Western Europe
# 116912                  187.58  Northern Europe
# 131583                   45.00  Northern Europe
# 143213                   34.80  Northern Europe
# 147133                  264.96   Western Europe
# 148607                  686.07  Southern Europe
#
#                                  Order State Order Status  \
# 5217                               Normandía   PROCESSING
# 13617                              Lombardía     COMPLETE
# 15793              Provenza-Alpes-Costa Azul     COMPLETE
# 16778      Mecklemburgo-Pomerania Occidental     COMPLETE
# 19518                             Inglaterra     COMPLETE
# 35671              Provenza-Alpes-Costa Azul     COMPLETE
# 59044                             Inglaterra      ON_HOLD
# 76906     Aquitania-Lemosín-Poitou-Charentes     COMPLETE
# 83124                                Liguria      ON_HOLD
# 91112   Languedoc-Rosellón-Mediodía-Pirineos       CLOSED
# 116912                            Inglaterra     COMPLETE
# 131583                            Inglaterra     COMPLETE
# 143213                                Dublín     COMPLETE
# 147133                               Bretaña      ON_HOLD
# 148607                              Cataluña     COMPLETE
#
#                Product Name  Product Price   Shipping Mode
# 5217    SOLE E35 Elliptical        1999.99  Standard Class
# 13617   SOLE E35 Elliptical        1999.99  Standard Class
# 15793   SOLE E35 Elliptical        1999.99  Standard Class
# 16778   SOLE E35 Elliptical        1999.99  Standard Class
# 19518   SOLE E35 Elliptical        1999.99    Second Class
# 35671   SOLE E35 Elliptical        1999.99    Second Class
# 59044   SOLE E35 Elliptical        1999.99  Standard Class
# 76906   SOLE E35 Elliptical        1999.99     First Class
# 83124   SOLE E35 Elliptical        1999.99  Standard Class
# 91112   SOLE E35 Elliptical        1999.99  Standard Class
# 116912  SOLE E35 Elliptical        1999.99     First Class
# 131583  SOLE E35 Elliptical        1999.99  Standard Class
# 143213  SOLE E35 Elliptical        1999.99  Standard Class
# 147133  SOLE E35 Elliptical        1999.99  Standard Class
# 148607  SOLE E35 Elliptical        1999.99  Standard Class

# %%
import matplotlib.pyplot as plt

# Filter data where Sales is between 0 and 250
sales_0_250_df = df[(df["Sales"] >= 0) & (df["Sales"] <= 250)]

print("Number of records:", len(sales_0_250_df))

# Scatter Plot
plt.figure(figsize=(8,6))

plt.scatter(
    sales_0_250_df["Sales"],
    sales_0_250_df["Benefit per order"],
    s=20,
    alpha=0.6
)

plt.title("Sales vs Benefit per Order (Sales: 0 to 250)")
plt.xlabel("Sales")
plt.ylabel("Benefit per Order")
plt.grid(True)

plt.show()
# Out:
# Number of records: 131586

# %%
import matplotlib.pyplot as plt

# Filter data where Sales is between 250 and 500
sales_250_500_df = df[(df["Sales"] >= 250) & (df["Sales"] <= 500)]

print("Number of records:", len(sales_250_500_df))

# Scatter Plot
plt.figure(figsize=(8,6))

plt.scatter(
    sales_250_500_df["Sales"],
    sales_250_500_df["Benefit per order"],
    s=20,
    alpha=0.6
)

plt.title("Sales vs Benefit per Order (Sales: 250 to 500)")
plt.xlabel("Sales")
plt.ylabel("Benefit per Order")
plt.grid(True)

plt.show()
# Out:
# Number of records: 52186

# %%
import matplotlib.pyplot as plt

# Filter data where Sales is between 500 and 1000
sales_500_1000_df = df[(df["Sales"] >= 500) & (df["Sales"] <= 1000)]

print("Number of records:", len(sales_500_1000_df))

# Scatter Plot
plt.figure(figsize=(8,6))

plt.scatter(
    sales_500_1000_df["Sales"],
    sales_500_1000_df["Benefit per order"],
    s=20,
    alpha=0.6
)

plt.title("Sales vs Benefit per Order (Sales: 500 to 1000)")
plt.xlabel("Sales")
plt.ylabel("Benefit per Order")
plt.grid(True)

plt.show()
# Out:
# Number of records: 530

# %%
import matplotlib.pyplot as plt

# Filter data where Sales is between 1000 and 2000
sales_1000_2000_df = df[(df["Sales"] >= 1000) & (df["Sales"] <= 2000)]

print("Number of records:", len(sales_1000_2000_df))

# Scatter Plot
plt.figure(figsize=(8,6))

plt.scatter(
    sales_1000_2000_df["Sales"],
    sales_1000_2000_df["Benefit per order"],
    s=20,
    alpha=0.6
)

plt.title("Sales vs Benefit per Order (Sales: 1000 to 2000)")
plt.xlabel("Sales")
plt.ylabel("Benefit per Order")
plt.grid(True)

plt.show()
# Out:
# Number of records: 457

# %%
import matplotlib.pyplot as plt

# Total Sales and Total Benefit
values = [
    df["Sales"].sum(),
    df["Benefit per order"].sum()
]

labels = ["Total Sales", "Total Benefit per Order"]

plt.figure(figsize=(7,7))

plt.pie(
    values,
    labels=labels,
    autopct='%1.1f%%',
    startangle=90
)

plt.title("Total Sales vs Total Benefit per Order")

plt.show()

# %%
import matplotlib.pyplot as plt

profit_by_segment = df.groupby("Customer Segment")["Order Profit Per Order"].sum()

plt.figure(figsize=(8,5))
profit_by_segment.plot(kind="bar")

plt.title("Total Profit by Customer Segment")
plt.xlabel("Customer Segment")
plt.ylabel("Total Profit")

plt.show()

# %%
import matplotlib.pyplot as plt

# Filter only loss-making orders
loss_df = df[df["Order Profit Per Order"] < 0]

loss_by_segment = loss_df.groupby("Customer Segment")["Order Profit Per Order"].sum()

plt.figure(figsize=(8,5))
loss_by_segment.plot(kind="bar", color="red")

plt.title("Total Loss by Customer Segment")
plt.xlabel("Customer Segment")
plt.ylabel("Total Loss")

plt.show()

# %%
top_loss_customers = (
    loss_df.groupby("Customer Id")["Order Profit Per Order"]
    .sum()
    .sort_values()
    .head(10)
)

plt.figure(figsize=(10,5))
top_loss_customers.plot(kind="bar", color="red")

plt.title("Top 10 Customers with Highest Loss")
plt.xlabel("Customer ID")
plt.ylabel("Loss")

plt.show()

# %%
top_100_customers_df = (
    df.groupby(["Customer Id", "Customer Fname", "Customer Lname"])["Order Profit Per Order"]
      .sum()
      .reset_index()
      .sort_values(by="Order Profit Per Order", ascending=False)
      .head(30)
)

top_100_customers_df
# Out:
#        Customer Id Customer Fname Customer Lname  Order Profit Per Order
# 2612          2641          Betty         Spears                 2441.97
# 1636          1657          Betty       Phillips                 2196.92
# 9755          9833          Jacob          Smith                 1938.39
# 2597          2626          Laura          Smith                 1928.57
# 4958          5004        Dorothy       Friedman                 1917.99
# 3697          3735           Mary          Lewis                 1906.36
# 741            749          Jesse       Matthews                 1855.15
# 5509          5560           Mary      Rodriguez                 1831.46
# 10875        10967      Alexander     Cunningham                 1822.33
# 5007          5053           Mary          Smith                 1813.34
# 2198          2224            Ann        Mercado                 1799.87
# 5129          5175           Mary       Sullivan                 1754.48
# 12124        12226       Nicholas          Smith                 1717.29
# 1133          1148           Mary       Anderson                 1716.96
# 9292          9368           Mary        Cabrera                 1700.64
# 10505        10591        Deborah       Humphrey                 1698.59
# 5171          5217          David          Smith                 1698.08
# 6639          6696           Mary        Spencer                 1696.08
# 2768          2800         Edward      Hernandez                 1680.45
# 2691          2723           Mary          Brady                 1674.83
# 9437          9513          Brian           Rice                 1672.87
# 475            482          Megan         Moreno                 1668.63
# 12183        12285        Patrick          Mcgee                 1663.41
# 3670          3708           Judy         Miller                 1652.74
# 11125        11218          Louis          Novak                 1631.37
# 7535          7597      Catherine          Smith                 1627.17
# 10611        10699           Mary            Lee                 1623.58
# 2154          2180        Shirley          Smith                 1623.26
# 1556          1577           Mary          Smith                 1620.48
# 6728          6785           Mary         Davila                 1603.75

# %%
top_100_customers = (
    df.groupby("Customer Id")
      .agg({
          "Customer Fname": "first",
          "Customer Lname": "first",
          "Customer Segment": "first",
          "Customer City": "first",
          "Customer State": "first",
          "Customer Country": "first",
          "Customer Street": "first",
          "Market": "first",
          "Latitude": "first",
          "Longitude": "first",
          "Order Profit Per Order": "sum",
          "Sales": "sum",
          "Order Item Quantity": "sum"
      })
      .rename(columns={
          "Order Profit Per Order": "Total Profit",
          "Sales": "Total Sales",
          "Order Item Quantity": "Total Quantity"
      })
      .sort_values(by="Total Profit", ascending=False)
      .head(30)
      .reset_index()
)

top_100_customers
# Out:
#     Customer Id Customer Fname Customer Lname Customer Segment  \
# 0          2641          Betty         Spears         Consumer
# 1          1657          Betty       Phillips         Consumer
# 2          9833          Jacob          Smith         Consumer
# 3          2626          Laura          Smith         Consumer
# 4          5004        Dorothy       Friedman      Home Office
# 5          3735           Mary          Lewis        Corporate
# 6           749          Jesse       Matthews         Consumer
# 7          5560           Mary      Rodriguez        Corporate
# 8         10967      Alexander     Cunningham         Consumer
# 9          5053           Mary          Smith        Corporate
# 10         2224            Ann        Mercado        Corporate
# 11         5175           Mary       Sullivan        Corporate
# 12        12226       Nicholas          Smith         Consumer
# 13         1148           Mary       Anderson         Consumer
# 14         9368           Mary        Cabrera         Consumer
# 15        10591        Deborah       Humphrey        Corporate
# 16         5217          David          Smith      Home Office
# 17         6696           Mary        Spencer        Corporate
# 18         2800         Edward      Hernandez      Home Office
# 19         2723           Mary          Brady         Consumer
# 20         9513          Brian           Rice        Corporate
# 21          482          Megan         Moreno         Consumer
# 22        12285        Patrick          Mcgee         Consumer
# 23         3708           Judy         Miller         Consumer
# 24        11218          Louis          Novak         Consumer
# 25         7597      Catherine          Smith        Corporate
# 26        10699           Mary            Lee         Consumer
# 27         2180        Shirley          Smith        Corporate
# 28         1577           Mary          Smith      Home Office
# 29         6785           Mary         Davila        Corporate
#
#       Customer City Customer State Customer Country  \
# 0        Carrollton             TX          EE. UU.
# 1            Caguas             PR      Puerto Rico
# 2            Caguas             PR      Puerto Rico
# 3         Oceanside             CA          EE. UU.
# 4             Miami             FL          EE. UU.
# 5         El Centro             CA          EE. UU.
# 6            Caguas             PR      Puerto Rico
# 7            Caguas             PR      Puerto Rico
# 8            Caguas             PR      Puerto Rico
# 9            Caguas             PR      Puerto Rico
# 10           Caguas             PR      Puerto Rico
# 11  Huntington Park             CA          EE. UU.
# 12    Staten Island             NY          EE. UU.
# 13          Augusta             GA          EE. UU.
# 14           Caguas             PR      Puerto Rico
# 15         Plymouth             MA          EE. UU.
# 16        Livermore             CA          EE. UU.
# 17       Alpharetta             GA          EE. UU.
# 18          Detroit             MI          EE. UU.
# 19           Caguas             PR      Puerto Rico
# 20           Denver             CO          EE. UU.
# 21           Caguas             PR      Puerto Rico
# 22           Caguas             PR      Puerto Rico
# 23      Westerville             OH          EE. UU.
# 24     Murfreesboro             TN          EE. UU.
# 25        Paramount             CA          EE. UU.
# 26     Jacksonville             FL          EE. UU.
# 27      Stockbridge             GA          EE. UU.
# 28           Caguas             PR      Puerto Rico
# 29           Caguas             PR      Puerto Rico
#
#                  Customer Street        Market   Latitude   Longitude  \
# 0       6398 Indian Brook Valley          USCA  32.965931  -96.849022
# 1         1475 Red Berry Village          USCA  18.244795  -66.370506
# 2     1043 Golden Timber Impasse        Europe  18.237686  -66.370514
# 3               4791 Sunny Downs        Africa  33.216427 -117.270653
# 4              6461 Silver Heath         LATAM  25.584570  -80.373611
# 5                  3569 Red Dell          USCA  32.792953 -115.558807
# 6        529 Cotton Branch Grove        Africa  18.227573  -66.043991
# 7      4687 Stony Goose Crossing         LATAM  18.210855  -66.370636
# 8          7373 Pleasant Estates  Pacific Asia  18.215086  -66.370560
# 9        870 Amber Quail Circuit        Europe  18.223675  -66.370522
# 10         6355 Grand Horse Port        Europe  18.259966  -66.370590
# 11     9672 Green Mountain Pines         LATAM  33.977638 -118.220688
# 12  3612 Silver Autumn Extension  Pacific Asia  40.584415  -74.159920
# 13                7213 Cozy Quay          USCA  33.521042  -82.049355
# 14            7464 Quaking Stead          USCA  18.225262  -66.370529
# 15                 141 Honey Way          USCA  41.921566  -70.793625
# 16               6906 Quiet Rise          USCA  37.390053 -121.468849
# 17        9726 Gentle Expressway         LATAM  33.998508  -84.279381
# 18          7592 Heather Circuit         LATAM  42.417259  -83.155090
# 19          7231 Grand Turnabout        Europe  18.270039  -66.370529
# 20      4388 Burning Goose Ridge          USCA  39.689751 -105.024590
# 21             1591 Foggy Meadow        Europe  18.227577  -66.045624
# 22               2059 Sunny Cape         LATAM  18.297915  -66.370506
# 23           7774 Broad Crossing         LATAM  40.118351  -82.928108
# 24        3614 Golden Expressway         LATAM  35.818367  -86.148376
# 25     7554 Stony Goose Crossing  Pacific Asia  33.905682 -118.160255
# 26       7320 Wishing Rise Mall         Africa  30.353422  -81.513092
# 27        8668 Emerald Elk Mount        Europe  33.549240  -84.256500
# 28             5274 Hidden Mall         Europe  18.294447  -66.370544
# 29             9214 Cotton Place        Europe  18.292625  -66.370621
#
#     Total Profit  Total Sales  Total Quantity
# 0        2441.97      9130.92              90
# 1        2196.92      9223.71             111
# 2        1938.39      6059.38              48
# 3        1928.57      6274.36              55
# 4        1917.99      8164.70             114
# 5        1906.36      6019.33              61
# 6        1855.15      7649.38              64
# 7        1831.46      6528.21              74
# 8        1822.33      5734.41              64
# 9        1813.34      7411.32              67
# 10       1799.87      6774.46              60
# 11       1754.48      6047.44              62
# 12       1717.29      7032.28              76
# 13       1716.96      6524.42              55
# 14       1700.64      6604.49              67
# 15       1698.59      7889.05              99
# 16       1698.08      7559.19              69
# 17       1696.08      6927.01              82
# 18       1680.45      5443.48              53
# 19       1674.83      7719.08              84
# 20       1672.87      5784.19              67
# 21       1668.63      6689.26              76
# 22       1663.41      7659.12              69
# 23       1652.74      8275.09              82
# 24       1631.37      6277.31              57
# 25       1627.17      6555.33              60
# 26       1623.58      6474.44              61
# 27       1623.26      5969.44              46
# 28       1620.48      7309.33              78
# 29       1603.75      4547.46              45

# %%
# Top 5 Most Sold Products
top_5_products = (
    df.groupby("Product Name")["Order Item Quantity"]
      .sum()
      .sort_values(ascending=False)
      .head(5)
)

print(top_5_products)
# Out:
# Product Name
# Perfect Fitness Perfect Rip Deck                 73698
# Nike Men's Dri-FIT Victory Golf Polo             62956
# O'Brien Men's Neoprene Life Vest                 57803
# Nike Men's Free 5.0+ Running Shoe                36680
# Under Armour Girls' Toddler Spine Surge Runni    31735
# Name: Order Item Quantity, dtype: int64

# %%
overall_loss_products = (
    df.groupby("Product Name")
      .agg(
          Total_Loss=("Order Profit Per Order", "sum"),
          Total_Orders=("Product Name", "count"),
          Total_Sales=("Sales", "sum"),
          Total_Quantity=("Order Item Quantity", "sum")
      )
      .reset_index()
)

overall_loss_products = overall_loss_products[
    overall_loss_products["Total_Loss"] < 0
]

overall_loss_products = overall_loss_products.sort_values(
    by="Total_Loss",
    ascending=True
)

overall_loss_products
# Out:
#                               Product Name  Total_Loss  Total_Orders  \
# 77                     SOLE E35 Elliptical     -965.12            15
# 9   Bushnell Pro X7 Jolt Slope Rangefinder     -255.95            11
# 76                     SOLE E25 Elliptical     -169.56            10
#
#     Total_Sales  Total_Quantity
# 77     29999.85              15
# 9       6599.89              11
# 76      9999.90              10

# %%
# Separate profitable and loss-making orders
profit_orders = df[df["Order Profit Per Order"] > 0]
loss_orders = df[df["Order Profit Per Order"] < 0]

# Calculate totals
total_profit = profit_orders["Order Profit Per Order"].sum()
total_loss = loss_orders["Order Profit Per Order"].sum()   # Negative value
net_profit = df["Order Profit Per Order"].sum()

print("Total Profit :", round(total_profit, 2))
print("Total Loss   :", round(total_loss, 2))
print("Net Profit   :", round(net_profit, 2))
# Out:
# Total Profit : 7850450.32
# Total Loss   : -3883547.35
# Net Profit   : 3966902.97

# %%
# Total Profit (positive values only)
total_profit = df[df["Order Profit Per Order"] > 0]["Order Profit Per Order"].sum()

# Total Loss (convert to positive)
total_loss = abs(df[df["Order Profit Per Order"] < 0]["Order Profit Per Order"].sum())

# Profit-to-Loss Ratio
ratio = total_profit / total_loss

print(f"Total Profit : {total_profit:.2f}")
print(f"Total Loss   : {total_loss:.2f}")
print(f"Profit : Loss Ratio = {ratio:.2f} : 1")
# Out:
# Total Profit : 7850450.32
# Total Loss   : 3883547.35
# Profit : Loss Ratio = 2.02 : 1

# %%
# Product-wise Quantity Sold and Total Profit
least_bought_loss_products = (
    df.groupby("Product Name")
      .agg(
          Total_Quantity=("Order Item Quantity", "sum"),
          Total_Profit=("Order Profit Per Order", "sum"),
          Total_Sales=("Sales", "sum")
      )
      .reset_index()
)

# Keep only products with overall loss
least_bought_loss_products = least_bought_loss_products[
    least_bought_loss_products["Total_Profit"] < 0
]

# Sort by least quantity sold
least_bought_loss_products = least_bought_loss_products.sort_values(
    by=["Total_Quantity", "Total_Profit"],
    ascending=[True, True]
)

least_bought_loss_products
# Out:
#                               Product Name  Total_Quantity  Total_Profit  \
# 76                     SOLE E25 Elliptical              10       -169.56
# 9   Bushnell Pro X7 Jolt Slope Rangefinder              11       -255.95
# 77                     SOLE E35 Elliptical              15       -965.12
#
#     Total_Sales
# 76      9999.90
# 9       6599.89
# 77     29999.85

# %%
# Products that have at least one loss-making order
products_with_loss = (
    df[df["Order Profit Per Order"] < 0]["Product Name"]
      .drop_duplicates()
      .sort_values()
      .reset_index(drop=True)
)

products_with_loss
# Out:
# 0                                 Adult dog supplies
# 1                                       Baby sweater
# 2                            Bag Boy Beverage Holder
# 3                             Bag Boy M330 Push Cart
# 4                  Bowflex SelectTech 1090 Dumbbells
#                            ...
# 113            adidas Kids' F5 Messi FG Soccer Cleat
# 114       adidas Men's F10 Messi TRX FG Soccer Cleat
# 115        adidas Men's Germany Black Crest Away Tee
# 116    adidas Youth Germany Black/Red Away Match Soc
# 117                 insta-bed Neverflat Air Mattress
# Name: Product Name, Length: 118, dtype: object

# %%
# Total unique products
total_products = df["Product Name"].nunique()

print("Total Products:", total_products)
# Out:
# Total Products: 118

# %%
# Hero Product Analysis
hero_products = (
    df.groupby("Product Name")
      .apply(lambda x: pd.Series({
          "Times Sold": len(x),
          "Total Quantity Sold": x["Order Item Quantity"].sum(),
          "Loss Count": (x["Order Profit Per Order"] < 0).sum(),
          "Total Loss": abs(
              x.loc[x["Order Profit Per Order"] < 0,
                    "Order Profit Per Order"].sum()
          ),
          "Total Profit": x.loc[
              x["Order Profit Per Order"] > 0,
              "Order Profit Per Order"
          ].sum(),
          "Net Profit": x["Order Profit Per Order"].sum(),
          "Total Sales Value": x["Sales"].sum()
      }))
      .reset_index()
)

# Keep only profitable products
hero_products = hero_products[
    hero_products["Net Profit"] > 0
]

# Sort by:
# 1. Highest Net Profit
# 2. Lowest Loss Count
# 3. Highest Times Sold
hero_products = hero_products.sort_values(
    by=["Net Profit", "Loss Count", "Times Sold"],
    ascending=[False, True, False]
)

# Top 10 Hero Products
top_10_hero_products = hero_products.head(10)

top_10_hero_products
# Out:
# C:\Users\MSI\AppData\Local\Temp\ipykernel_18164\1533512306.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: pd.Series({
#                                       Product Name  Times Sold  \
# 24       Field & Stream Sportsman 16 Gun Fire Safe     17325.0
# 71                Perfect Fitness Perfect Rip Deck     24515.0
# 21   Diamondback Women's Serene Classic Comfort Bi     13729.0
# 61               Nike Men's Free 5.0+ Running Shoe     12169.0
# 59            Nike Men's Dri-FIT Victory Golf Polo     21035.0
# 70                     Pelican Sunstream 100 Kayak     15500.0
# 67                O'Brien Men's Neoprene Life Vest     19298.0
# 56         Nike Men's CJ Elite 2 TD Football Cleat     22246.0
# 102  Under Armour Girls' Toddler Spine Surge Runni     10617.0
# 18                                     Dell Laptop       442.0
#
#      Total Quantity Sold  Loss Count  Total Loss  Total Profit  Net Profit  \
# 24               17325.0      3209.0   728570.95    1484791.71   756220.76
# 71               73698.0      4583.0   450978.29     944806.59   493828.30
# 21               13729.0      2590.0   443082.23     870537.80   427455.57
# 61               36680.0      2271.0   400015.04     779930.86   379915.82
# 59               62956.0      3923.0   323772.87     674193.90   350421.03
# 70               15500.0      2916.0   332804.25     656880.62   324076.37
# 67               57803.0      3617.0   298637.48     617088.91   318451.43
# 56               22246.0      4169.0   309269.70     621172.52   311902.82
# 102              31735.0      2085.0   139661.49     265940.00   126278.51
# 18                 442.0        73.0    74967.13     144623.94    69656.81
#
#      Total Sales Value
# 24          6929653.50
# 71          4421143.02
# 21          4118425.42
# 61          3667633.20
# 59          3147800.00
# 70          3099845.00
# 67          2888993.94
# 56          2891757.54
# 102         1269082.65
# 18           663000.00

# %%
# Top 10 Most Sold Products

top_10_sold_products = (
    df.groupby("Product Name")
      .agg(
          Times_Sold=("Product Name", "count"),
          Total_Quantity_Sold=("Order Item Quantity", "sum"),
          Total_Sales_Value=("Sales", "sum"),
          Total_Profit=("Order Profit Per Order", "sum")
      )
      .sort_values(by="Total_Quantity_Sold", ascending=False)
      .head(10)
      .reset_index()
)

top_10_sold_products
# Out:
#                                     Product Name  Times_Sold  \
# 0               Perfect Fitness Perfect Rip Deck       24515
# 1           Nike Men's Dri-FIT Victory Golf Polo       21035
# 2               O'Brien Men's Neoprene Life Vest       19298
# 3              Nike Men's Free 5.0+ Running Shoe       12169
# 4  Under Armour Girls' Toddler Spine Surge Runni       10617
# 5        Nike Men's CJ Elite 2 TD Football Cleat       22246
# 6      Field & Stream Sportsman 16 Gun Fire Safe       17325
# 7                    Pelican Sunstream 100 Kayak       15500
# 8  Diamondback Women's Serene Classic Comfort Bi       13729
# 9                       ENO Atlas Hammock Straps         323
#
#    Total_Quantity_Sold  Total_Sales_Value  Total_Profit
# 0                73698         4421143.02     493828.30
# 1                62956         3147800.00     350421.03
# 2                57803         2888993.94     318451.43
# 3                36680         3667633.20     379915.82
# 4                31735         1269082.65     126278.51
# 5                22246         2891757.54     311902.82
# 6                17325         6929653.50     756220.76
# 7                15500         3099845.00     324076.37
# 8                13729         4118425.42     427455.57
# 9                  998           29930.02       2139.58

# %%
country_summary = (
    df.groupby("Order Country")
      .agg(
          Total_Orders=("Order Country", "count"),
          Total_Customers=("Customer Id", "nunique"),
          Total_Quantity_Sold=("Order Item Quantity", "sum"),
          Total_Sales=("Sales", "sum"),

          Total_Profit=("Order Profit Per Order",
                        lambda x: x[x > 0].sum()),

          Total_Loss=("Order Profit Per Order",
                      lambda x: abs(x[x < 0].sum())),

          Net_Profit=("Order Profit Per Order", "sum"),

          Loss_Count=("Order Profit Per Order",
                      lambda x: (x < 0).sum()),

          Avg_Order_Value=("Sales", "mean")
      )
      .reset_index()
)

country_summary["Profit_Loss_Ratio"] = (
    country_summary["Total_Profit"] /
    country_summary["Total_Loss"].replace(0, 1)
).round(2)

country_summary = country_summary.sort_values(
    by="Net_Profit",
    ascending=False
)

country_summary
# Out:
#             Order Country  Total_Orders  Total_Customers  Total_Quantity_Sold  \
# 48         Estados Unidos         24840             6102                54433
# 53                Francia         13222             4245                27676
# 102                México         13172             3706                28794
# 2                Alemania          9564             3188                19803
# 20                 Brasil          7987             2399                17405
# ..                    ...           ...              ...                  ...
# 98               Mongolia            79               28                  185
# 18   Bosnia y Herzegovina            45               16                   83
# 127                Ruanda            86               30                  185
# 146                Taiwán            29               13                   52
# 63          Guinea-Bissau            28                9                   58
#
#      Total_Sales  Total_Profit  Total_Loss  Net_Profit  Loss_Count  \
# 48    4879667.57    1052541.11   512128.04   540413.07        4649
# 53    2879942.31     618859.21   291030.63   327828.58        2391
# 102   2633195.24     565990.09   262711.72   303278.37        2341
# 2     2074171.78     438602.41   243775.33   194827.08        1928
# 20    1594319.92     344953.32   158239.68   186713.64        1465
# ..           ...           ...         ...         ...         ...
# 98      15481.74       2472.36     2758.59     -286.23          24
# 18       8869.09       1443.53     1770.91     -327.38          15
# 127     18913.02       3890.71     4220.73     -330.02          18
# 146      6396.33       1066.62     2441.16    -1374.54          11
# 63       5169.41        791.20     2239.92    -1448.72           7
#
#      Avg_Order_Value  Profit_Loss_Ratio
# 48        196.443944               2.06
# 53        217.814424               2.13
# 102       199.908536               2.15
# 2         216.872834               1.80
# 20        199.614363               2.18
# ..               ...                ...
# 98        195.971392               0.90
# 18        197.090889               0.82
# 127       219.918837               0.92
# 146       220.563103               0.44
# 63        184.621786               0.35
#
# [164 rows x 11 columns]

# %%
# Top 10 Countries by Net Profit

top_10_countries = (
    df.groupby("Order Country")
      .agg(
          Total_Customers=("Customer Id", "nunique"),
          Total_Orders=("Order Country", "count"),
          Total_Quantity_Sold=("Order Item Quantity", "sum"),
          Total_Sales=("Sales", "sum"),

          Total_Profit=("Order Profit Per Order",
                        lambda x: x[x > 0].sum()),

          Total_Loss=("Order Profit Per Order",
                      lambda x: abs(x[x < 0].sum())),

          Net_Profit=("Order Profit Per Order", "sum"),

          Loss_Count=("Order Profit Per Order",
                      lambda x: (x < 0).sum())
      )
      .sort_values(by="Net_Profit", ascending=False)
      .head(10)
      .reset_index()
)

top_10_countries
# Out:
#     Order Country  Total_Customers  Total_Orders  Total_Quantity_Sold  \
# 0  Estados Unidos             6102         24840                54433
# 1         Francia             4245         13222                27676
# 2          México             3706         13172                28794
# 3        Alemania             3188          9564                19803
# 4          Brasil             2399          7987                17405
# 5     Reino Unido             2582          7302                15214
# 6       Australia             3586          8497                16766
# 7           China             2529          5758                11448
# 8          Italia             1785          4989                10218
# 9           India             2094          4783                 9539
#
#    Total_Sales  Total_Profit  Total_Loss  Net_Profit  Loss_Count
# 0   4879667.57    1052541.11   512128.04   540413.07        4649
# 1   2879942.31     618859.21   291030.63   327828.58        2391
# 2   2633195.24     565990.09   262711.72   303278.37        2341
# 3   2074171.78     438602.41   243775.33   194827.08        1928
# 4   1594319.92     344953.32   158239.68   186713.64        1465
# 5   1612094.82     345307.70   164364.82   180942.88        1347
# 6   1694621.64     360554.56   190512.98   170041.58        1613
# 7   1172902.09     247547.08   125356.16   122190.92        1071
# 8   1072181.65     230535.43   108989.96   121545.47         912
# 9    962396.68     202379.81   102632.99    99746.82         921

# %%
# Top 10 Products
top_products = (
    df.groupby("Product Name")["Order Item Quantity"]
      .sum()
      .nlargest(10)
      .index
)

# Top 10 Countries
top_countries = (
    df.groupby("Order Country")["Sales"]
      .sum()
      .nlargest(10)
      .index
)

comparison_df = df[
    (df["Product Name"].isin(top_products)) &
    (df["Order Country"].isin(top_countries))
]

comparison = (
    comparison_df.pivot_table(
        index="Order Country",
        columns="Product Name",
        values="Order Item Quantity",
        aggfunc="sum",
        fill_value=0
    )
)

comparison
# Out:
# Product Name    Diamondback Women's Serene Classic Comfort Bi  \
# Order Country
# Alemania                                                  742
# Australia                                                 558
# Brasil                                                    673
# China                                                     351
# Estados Unidos                                           1973
# Francia                                                   962
# India                                                     324
# Italia                                                    360
# México                                                   1088
# Reino Unido                                               566
#
# Product Name    ENO Atlas Hammock Straps  \
# Order Country
# Alemania                              30
# Australia                             54
# Brasil                                31
# China                                 47
# Estados Unidos                       156
# Francia                               50
# India                                 20
# Italia                                18
# México                                82
# Reino Unido                           28
#
# Product Name    Field & Stream Sportsman 16 Gun Fire Safe  \
# Order Country
# Alemania                                              911
# Australia                                             742
# Brasil                                                801
# China                                                 487
# Estados Unidos                                       2499
# Francia                                              1269
# India                                                 400
# Italia                                                472
# México                                               1323
# Reino Unido                                           689
#
# Product Name    Nike Men's CJ Elite 2 TD Football Cleat  \
# Order Country
# Alemania                                           1155
# Australia                                           942
# Brasil                                             1002
# China                                               642
# Estados Unidos                                     3267
# Francia                                            1544
# India                                               508
# Italia                                              632
# México                                             1728
# Reino Unido                                         879
#
# Product Name    Nike Men's Dri-FIT Victory Golf Polo  \
# Order Country
# Alemania                                        3293
# Australia                                       2449
# Brasil                                          3093
# China                                           1619
# Estados Unidos                                  9210
# Francia                                         4635
# India                                           1427
# Italia                                          1679
# México                                          4753
# Reino Unido                                     2552
#
# Product Name    Nike Men's Free 5.0+ Running Shoe  \
# Order Country
# Alemania                                     2010
# Australia                                    1622
# Brasil                                       1652
# China                                        1018
# Estados Unidos                               5060
# Francia                                      2671
# India                                         760
# Italia                                        934
# México                                       2701
# Reino Unido                                  1590
#
# Product Name    O'Brien Men's Neoprene Life Vest  Pelican Sunstream 100 Kayak  \
# Order Country
# Alemania                                    2842                          814
# Australia                                   2379                          637
# Brasil                                      2668                          711
# China                                       1682                          409
# Estados Unidos                              8058                         2228
# Francia                                     4077                         1136
# India                                       1256                          341
# Italia                                      1568                          455
# México                                      4551                         1207
# Reino Unido                                 2364                          635
#
# Product Name    Perfect Fitness Perfect Rip Deck  \
# Order Country
# Alemania                                    3778
# Australia                                   2926
# Brasil                                      3225
# China                                       1918
# Estados Unidos                             10818
# Francia                                     5383
# India                                       1621
# Italia                                      1910
# México                                      5626
# Reino Unido                                 2925
#
# Product Name    Under Armour Girls' Toddler Spine Surge Runni
# Order Country
# Alemania                                                 1656
# Australia                                                1207
# Brasil                                                   1481
# China                                                     865
# Estados Unidos                                           4555
# Francia                                                  2547
# India                                                     796
# Italia                                                    802
# México                                                   2508
# Reino Unido                                              1149

# %%
correlation = df[["Order Item Discount", "Order Item Profit Ratio"]].corr()

print(correlation)
# Out:
#                          Order Item Discount  Order Item Profit Ratio
# Order Item Discount                 1.000000                -0.002788
# Order Item Profit Ratio            -0.002788                 1.000000

# %%
# Create Discount Groups
df["Discount Range"] = pd.cut(
    df["Order Item Discount"],
    bins=[0,50,100,200,500,1000,2000],
    labels=[
        "0-50",
        "51-100",
        "101-200",
        "201-500",
        "501-1000",
        "1000+"
    ]
)

discount_analysis = (
    df.groupby("Discount Range")
      .agg(
          Average_Profit_Margin=("Order Item Profit Ratio","mean"),
          Average_Profit=("Order Profit Per Order","mean"),
          Average_Sales=("Sales","mean"),
          Orders=("Order Item Discount","count")
      )
)

discount_analysis
# Out:
# C:\Users\MSI\AppData\Local\Temp\ipykernel_18164\2609929628.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("Discount Range")
#                 Average_Profit_Margin  Average_Profit  Average_Sales  Orders
# Discount Range
# 0-50                         0.120307       19.954929     183.635143  154289
# 51-100                       0.119612       35.937969     373.487610   15655
# 101-200                      0.117995       83.626118     826.566015     389
# 201-500                      0.129241      161.551139    1525.315949     158
# 501-1000                          NaN             NaN            NaN       0
# 1000+                             NaN             NaN            NaN       0

# %%
# Top 30 Customers with Most Orders

top_30_customers = (
    df.groupby("Customer Id")
      .agg(
          Customer_Fname=("Customer Fname", "first"),
          Customer_Lname=("Customer Lname", "first"),
          Customer_Segment=("Customer Segment", "first"),
          Customer_City=("Customer City", "first"),
          Customer_State=("Customer State", "first"),
          Customer_Country=("Customer Country", "first"),

          Total_Orders=("Customer Id", "count"),
          Total_Quantity=("Order Item Quantity", "sum"),
          Total_Sales=("Sales", "sum"),

          Total_Profit=("Order Profit Per Order",
                        lambda x: x[x > 0].sum()),

          Total_Loss=("Order Profit Per Order",
                      lambda x: abs(x[x < 0].sum())),

          Net_Profit=("Order Profit Per Order", "sum"),

          Avg_Order_Value=("Sales", "mean")
      )
      .sort_values(by="Total_Orders", ascending=False)
      .head(30)
      .reset_index()
)

top_30_customers
# Out:
#     Customer Id Customer_Fname Customer_Lname Customer_Segment Customer_City  \
# 0          5654          Jerry          Smith      Home Office        Caguas
# 1          5004        Dorothy       Friedman      Home Office         Miami
# 2         10591        Deborah       Humphrey        Corporate      Plymouth
# 3          9371           Mary      Patterson         Consumer      Meridian
# 4          3708           Judy         Miller         Consumer   Westerville
# 5          5715          Kelly          Smith        Corporate        Caguas
# 6          1443         Denise          Cohen         Consumer   West Orange
# 7         12284           Mary          Smith         Consumer     New Haven
# 8          2641          Betty         Spears         Consumer    Carrollton
# 9           791           Mary          Smith        Corporate        Canton
# 10         2970        Kenneth          Smith         Consumer   Brownsville
# 11         1288         Evelyn       Thompson      Home Office        Caguas
# 12        10235         Joseph          Singh        Corporate        Caguas
# 13         3710         Ashley          Smith         Consumer   Springfield
# 14         1657          Betty       Phillips         Consumer        Caguas
# 15         1464          Amber          Dixon         Consumer        Caguas
# 16         1588           Mary          Smith        Corporate        Caguas
# 17         5648         Joshua          Smith        Corporate       Memphis
# 18        11065          Aaron          Smith         Consumer      New York
# 19         8015           Mary      Blackburn      Home Office        Caguas
# 20         4663           Paul          Smith        Corporate      Columbus
# 21        11048          Randy           Ball        Corporate        Caguas
# 22         6950       Nicholas          Smith        Corporate       Marrero
# 23         6316           Kyle          Smith      Home Office        Caguas
# 24         7670           Anna          Smith        Corporate       Houston
# 25         3979           Mary         Wagner        Corporate        Caguas
# 26         5897           Mary        Griffin      Home Office      Newburgh
# 27         9821        Deborah          Smith         Consumer   New Bedford
# 28         4249           Mary         Butler         Consumer        Caguas
# 29          664          Bobby        Jimenez      Home Office       Holland
#
#    Customer_State Customer_Country  Total_Orders  Total_Quantity  Total_Sales  \
# 0              PR      Puerto Rico            47             103      8904.95
# 1              FL          EE. UU.            45             114      8164.70
# 2              MA          EE. UU.            45              99      7889.05
# 3              ID          EE. UU.            44              87      9299.03
# 4              OH          EE. UU.            44              82      8275.09
# 5              PR      Puerto Rico            44              99      8595.13
# 6              NJ          EE. UU.            43              86      8150.13
# 7              CT          EE. UU.            43             110      8258.62
# 8              TX          EE. UU.            43              90      9130.92
# 9              MI          EE. UU.            43              82     10524.17
# 10             TX          EE. UU.            42              79      7231.15
# 11             PR      Puerto Rico            42              89      9019.11
# 12             PR      Puerto Rico            42              78      8404.22
# 13             MO          EE. UU.            42              89      9019.10
# 14             PR      Puerto Rico            42             111      9223.71
# 15             PR      Puerto Rico            42              63      8409.22
# 16             PR      Puerto Rico            42              89      6694.19
# 17             TN          EE. UU.            41              83      7323.22
# 18             NY          EE. UU.            41             101      7450.05
# 19             PR      Puerto Rico            40              76      6910.89
# 20             GA          EE. UU.            40              91      8279.89
# 21             PR      Puerto Rico            40              84      7239.14
# 22             LA          EE. UU.            40              84      7951.12
# 23             PR      Puerto Rico            39              85      8105.18
# 24             TX          EE. UU.            39              67      7049.32
# 25             PR      Puerto Rico            39              94      6939.13
# 26             NY          EE. UU.            39              86      8061.12
# 27             MA          EE. UU.            39              85      7328.20
# 28             PR      Puerto Rico            39              94      8918.85
# 29             MI          EE. UU.            39              76      8394.26
#
#     Total_Profit  Total_Loss  Net_Profit  Avg_Order_Value
# 0        1821.78      776.42     1045.36       189.467021
# 1        2243.21      325.22     1917.99       181.437778
# 2        2030.08      331.49     1698.59       175.312222
# 3        1984.73      638.15     1346.58       211.341591
# 4        2256.64      603.90     1652.74       188.070227
# 5        1419.51     1596.96     -177.45       195.343864
# 6        1923.13      539.33     1383.80       189.537907
# 7        1769.56      307.10     1462.46       192.060930
# 8        2547.00      105.03     2441.97       212.346977
# 9        2074.59     2940.97     -866.38       244.748140
# 10       1605.29      554.85     1050.44       172.170238
# 11       1483.54     1080.43      403.11       214.740714
# 12       1850.30      467.22     1383.08       200.100476
# 13       1775.58      720.45     1055.13       214.740476
# 14       2250.85       53.93     2196.92       219.612143
# 15       1794.56      997.31      797.25       200.219524
# 16       1300.67     1922.40     -621.73       159.385476
# 17       1591.30      275.41     1315.89       178.615122
# 18       1649.99      957.00      692.99       181.708537
# 19       1514.87      544.65      970.22       172.772250
# 20       1907.43     1026.39      881.04       206.997250
# 21       1868.32     1077.24      791.08       180.978500
# 22       1956.89      495.00     1461.89       198.778000
# 23       1581.55      764.65      816.90       207.825128
# 24       1089.21      948.78      140.43       180.751795
# 25       1777.24      239.54     1537.70       177.926410
# 26       2005.32      588.72     1416.60       206.695385
# 27       1226.87     1060.47      166.40       187.902564
# 28       1968.60     1528.89      439.71       228.688462
# 29       1611.38     1679.83      -68.45       215.237436

# %%
# Sales if no discount had been given
df["Sales Without Discount"] = df["Sales"] + df["Order Item Discount"]

df[["Sales", "Order Item Discount", "Sales Without Discount"]].head()
# Out:
#     Sales  Order Item Discount  Sales Without Discount
# 0  499.95                27.50                  527.45
# 1  199.95                31.99                  231.94
# 2  199.99                18.00                  217.99
# 3  199.99                24.00                  223.99
# 4   50.00                10.00                   60.00

# %%
total_sales_without_discount = df["Sales Without Discount"].sum()

print("Total Sales Without Discount:", total_sales_without_discount)
# Out:
# Total Sales Without Discount: 40515112.70999999

# %%
total_discount = df["Order Item Discount"].sum()

print("Total Discount Given:", total_discount)
# Out:
# Total Discount Given: 3730378.4

# %%
df["Estimated Profit Without Discount"] = (
    df["Order Profit Per Order"] + df["Order Item Discount"]
)

estimated_profit = df["Estimated Profit Without Discount"].sum()

print("Estimated Profit Without Discount:", estimated_profit)
# Out:
# Estimated Profit Without Discount: 7697281.37

# %%
comparison = pd.DataFrame({
    "Current": [
        df["Sales"].sum(),
        df["Order Profit Per Order"].sum()
    ],
    "Without Discount": [
        df["Sales Without Discount"].sum(),
        df["Estimated Profit Without Discount"].sum()
    ]
}, index=["Total Sales", "Estimated Net Profit"])

comparison
# Out:
#                           Current  Without Discount
# Total Sales           36784734.31       40515112.71
# Estimated Net Profit   3966902.97        7697281.37

# %%
# Create discount percentage buckets
df["Discount Bucket"] = pd.cut(
    df["Order Item Discount Rate"],
    bins=[0, 0.05, 0.10, 0.15, 0.20, 0.25, 0.50, 1.00],
    labels=[
        "0-5%",
        "5-10%",
        "10-15%",
        "15-20%",
        "20-25%",
        "25-50%",
        "50%+"
    ],
    include_lowest=True
)

# %%
discount_threshold = (
    df.groupby("Discount Bucket")
      .agg(
          Orders=("Order Item Discount Rate", "count"),
          Avg_Discount=("Order Item Discount Rate", "mean"),
          Avg_Profit_Margin=("Order Item Profit Ratio", "mean"),
          Avg_Profit=("Order Profit Per Order", "mean"),
          Total_Profit=("Order Profit Per Order", "sum"),
          Avg_Sales=("Sales", "mean")
      )
      .reset_index()
)

discount_threshold
# Out:
# C:\Users\MSI\AppData\Local\Temp\ipykernel_18164\1270027860.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("Discount Bucket")
#   Discount Bucket  Orders  Avg_Discount  Avg_Profit_Margin  Avg_Profit  \
# 0            0-5%   60171      0.025001           0.122081   23.916745
# 1           5-10%   40116      0.080000           0.122668   23.095813
# 2          10-15%   30087      0.133333           0.117898   20.784363
# 3          15-20%   40116      0.177500           0.116907   19.544845
# 4          20-25%   10029      0.250000           0.127158   19.134183
# 5          25-50%       0           NaN                NaN         NaN
# 6            50%+       0           NaN                NaN         NaN
#
#    Total_Profit   Avg_Sales
# 0    1439094.48  203.721307
# 1     926511.63  203.755412
# 2     625339.12  203.801887
# 3     784061.02  203.825350
# 4     191896.72  203.841095
# 5          0.00         NaN
# 6          0.00         NaN

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))

plt.plot(
    discount_threshold["Discount Bucket"],
    discount_threshold["Avg_Profit_Margin"],
    marker="o",
    linewidth=2
)

plt.title("Discount Threshold vs Average Profit Margin")
plt.xlabel("Discount Bucket")
plt.ylabel("Average Profit Margin")

plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(10,5))

plt.bar(
    discount_threshold["Discount Bucket"],
    discount_threshold["Avg_Profit"]
)

plt.title("Average Profit per Order by Discount Bucket")
plt.xlabel("Discount Bucket")
plt.ylabel("Average Profit per Order")

plt.show()

# %%
print(discount_threshold[
    ["Discount Bucket",
     "Avg_Profit_Margin",
     "Avg_Profit"]
])
# Out:
#   Discount Bucket  Avg_Profit_Margin  Avg_Profit
# 0            0-5%           0.122081   23.916745
# 1           5-10%           0.122668   23.095813
# 2          10-15%           0.117898   20.784363
# 3          15-20%           0.116907   19.544845
# 4          20-25%           0.127158   19.134183
# 5          25-50%                NaN         NaN
# 6            50%+                NaN         NaN
